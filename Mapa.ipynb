# %%
# correr desde la terminal el comando <pip install geopandas>
# correr desde la terminal el comando <pip install descartes>
import os
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, Polygon

# %%
df = pd.read_csv('coord.csv')
crs = {"init": "epsg:4326"}
df.head()
# Out:
#    n  ao_inicio          x          y                      geopoint
# 0  1       2016  19.484049 -99.182773  19.4840488389,-99.1827730654
# 1  2       2016  19.440357 -99.173618     19.4403565998,-99.1736176
# 2  3       2016  19.399237 -99.192709  19.3992374679,-99.1927092929
# 3  4       2016  19.366661 -99.169106  19.3666607724,-99.1691056856
# 4  5       2016  19.243469 -99.173013  19.2434687338,-99.1730127583

# %%
geometry = [Point(xy) for xy in zip (df["x"],df["y"])]

# %%
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x7fb6d8a62940>,
#  <shapely.geometry.point.Point at 0x7fb6d8a627b8>,
#  <shapely.geometry.point.Point at 0x7fb6d8a62ba8>]

# %%
geo_df =  gpd.GeoDataFrame(df, crs="EPSG:4326",
                          geometry=geometry)
geo_df.head()
# Out:
#    n  ao_inicio          x          y                      geopoint  \
# 0  1       2016  19.484049 -99.182773  19.4840488389,-99.1827730654
# 1  2       2016  19.440357 -99.173618     19.4403565998,-99.1736176
# 2  3       2016  19.399237 -99.192709  19.3992374679,-99.1927092929
# 3  4       2016  19.366661 -99.169106  19.3666607724,-99.1691056856
# 4  5       2016  19.243469 -99.173013  19.2434687338,-99.1730127583
#
#                  geometry
# 0  POINT (19.484 -99.183)
# 1  POINT (19.440 -99.174)
# 2  POINT (19.399 -99.193)
# 3  POINT (19.367 -99.169)
# 4  POINT (19.243 -99.173)

# %%
fig, ax = plt.subplots(figsize = (15,15))
geo_df.plot(ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-43f813e9f795> in <module>
#       1 fig, ax = plt.subplots(figsize = (15,15))
# ----> 2 geo_df.plot(ax=ax)
#       3 plt.show()
#
# ~/.local/lib/python3.6/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     919         from there.
#     920         """
# --> 921         return plot_dataframe(self, *args, **kwargs)
#     922
#     923     plot.__doc__ = plot_dataframe.__doc__
#
# ~/.local/lib/python3.6/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     621             markersize=markersize,
#     622             aspect=aspect,
# --> 623             **style_kwds
#     624         )
#     625
#
# ~/.local/lib/python3.6/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     431         )
#     432
# --> 433     plt.draw()
#     434     return ax
#     435
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in draw()
#     715     the current figure.
#     716     """
# --> 717     gcf().canvas.draw_idle()
#     718
#     719
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1929         if not self._is_idle_drawing:
#    1930             with self._idle_draw_cntx():
# -> 1931                 self.draw(*args, **kwargs)
#    1932
#    1933     @cbook.deprecated("3.2")
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1710                 ax.apply_aspect(pos)
#    1711             else:
# -> 1712                 ax.apply_aspect()
#    1713
#    1714             for child in ax.get_children():
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in apply_aspect(self, position)
#    1479             box_aspect = aspect * self.get_data_ratio()
#    1480             pb = position.frozen()
# -> 1481             pb1 = pb.shrunk_to_aspect(box_aspect, pb, fig_aspect)
#    1482             self._set_position(pb1.anchored(self.get_anchor(), pb), 'active')
#    1483             return
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in shrunk_to_aspect(self, box_aspect, container, fig_aspect)
#     588         """
#     589         if box_aspect <= 0 or fig_aspect <= 0:
# --> 590             raise ValueError("'box_aspect' and 'fig_aspect' must be positive")
#     591         if container is None:
#     592             container = self
#
# ValueError: 'box_aspect' and 'fig_aspect' must be positive
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2077                             print_method, dpi=dpi, orientation=orientation),
#    2078                         draw_disabled=True)
# -> 2079                     self.figure.draw(renderer)
#    2080                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2081                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1710                 ax.apply_aspect(pos)
#    1711             else:
# -> 1712                 ax.apply_aspect()
#    1713
#    1714             for child in ax.get_children():
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in apply_aspect(self, position)
#    1479             box_aspect = aspect * self.get_data_ratio()
#    1480             pb = position.frozen()
# -> 1481             pb1 = pb.shrunk_to_aspect(box_aspect, pb, fig_aspect)
#    1482             self._set_position(pb1.anchored(self.get_anchor(), pb), 'active')
#    1483             return
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in shrunk_to_aspect(self, box_aspect, container, fig_aspect)
#     588         """
#     589         if box_aspect <= 0 or fig_aspect <= 0:
# --> 590             raise ValueError("'box_aspect' and 'fig_aspect' must be positive")
#     591         if container is None:
#     592             container = self
#
# ValueError: 'box_aspect' and 'fig_aspect' must be positive

# %%
ls
# Out:
#  Bases_de_datos/       Estimaciones.ipynb             LICENSE        README.md
#  Descriptivos.ipynb    Estimaciones2.ipynb           'Link base'     coord.csv
#  Descriptivos1.ipynb   Estimaciones_anuales.ipynb     Mapa.ipynb     shapes/
#  Descriptivos2.ipynb   Estimaciones_mensuales.ipynb   Mapita.ipynb

# %%
cd shapes
# Out:
# /home/jovyan/midirectorio/shapes

# %%
ls
# Out:
# coloniascdmx.dbf  coloniascdmx.prj  coloniascdmx.shp  coloniascdmx.shx

# %%
colonias = gpd.read_file("coloniascdmx.shp")

# %%
fig, ax = plt.subplots(figsize = (15,15))
colonias.plot (ax=ax)

# %%
fig, ax = plt.subplots(figsize = (15,15))
colonias.plot(ax=ax, alpha =.4, color ="black")
plt.show()
